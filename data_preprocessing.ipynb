# %% [markdown]
# ## Feature Engineering

# %%
import pandas as pd
import nltk

# %%
df = pd.read_pickle('clean_dataset.pkl')
df.head(3)
# Out:
#        imdbID              title    year                     genre  \
# 2008    35423     Kate & Leopold  2001.0  Comedy, Fantasy, Romance
# 7011    64994  Larks on a String  1990.0    Comedy, Drama, Romance
# 10044   81145     Me and the Kid  1993.0      Comedy, Crime, Drama
#
#             director                                               cast  \
# 2008   James Mangold  Meg Ryan, Hugh Jackman, Liev Schreiber, Brecki...
# 7011     Jir� Menzel  Rudolf Hrus�nsk�, Vlastimil Brodsk�, V�clav Ne...
# 10044     Dan Curtis  Danny Aiello, Alex Zuckerman, Joe Pantoliano, ...
#
#        imdbRating                                           fullplot  \
# 2008          6.3  Kate and her actor brother live in N.Y. in the...
# 7011          7.6  Prague in the early 1950's. Bourgeois elements...
# 10044         5.3  Two ex-cons, Harry (Aiello) and Roy (Pantolian...
#
#               language         country   type
# 2008   English, French             USA  movie
# 7011             Czech  Czechoslovakia  movie
# 10044          English             USA  movie

# %%
#convert the year column into decade 

df['year'] = pd.to_numeric(df['year'], errors='coerce')
df.dropna(subset=['year'], inplace=True)
df['decade'] = df['year'].apply(lambda x: x - x % 10)

# Drop the 'year' column
df.drop(['year'], axis=1, inplace=True)

# %%
# converting all the column values into list
def split_strip(row):
    new_row = []
    row = str(row)
    row = row.split(',')
    for i in row:
        i = i.strip()
        i = i.lower()
        new_row.append(i)

    return new_row

# %%
for i in df.columns:
    if i not in ['imdbID','title']:
        
        df[i] = df[i].apply(split_strip)

# %%
df.head(3)
# Out:
#        imdbID              title                       genre         director  \
# 2008    35423     Kate & Leopold  [comedy, fantasy, romance]  [james mangold]
# 7011    64994  Larks on a String    [comedy, drama, romance]    [jir� menzel]
# 10044   81145     Me and the Kid      [comedy, crime, drama]     [dan curtis]
#
#                                                     cast imdbRating  \
# 2008   [meg ryan, hugh jackman, liev schreiber, breck...      [6.3]
# 7011   [rudolf hrus�nsk�, vlastimil brodsk�, v�clav n...      [7.6]
# 10044  [danny aiello, alex zuckerman, joe pantoliano,...      [5.3]
#
#                                                 fullplot           language  \
# 2008   [kate and her actor brother live in n.y. in th...  [english, french]
# 7011   [prague in the early 1950's. bourgeois element...            [czech]
# 10044  [two ex-cons, harry (aiello) and roy (pantolia...          [english]
#
#                 country     type    decade
# 2008              [usa]  [movie]  [2000.0]
# 7011   [czechoslovakia]  [movie]  [1990.0]
# 10044             [usa]  [movie]  [1990.0]

# %%
## removing the inbetween spacas from director and cast names
def space_remover(row):
    new_row = []
    for i in row:
        i = i.replace(' ','')
        new_row.append(i)
    return new_row

df['director'] = df['director'].apply(space_remover)
df['cast'] = df['cast'].apply(space_remover)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string




def preprocess_sentences(sentences):
    
    sentences = [''.join([char for char in sentence if char not in string.punctuation]) for sentence in sentences]
    
    
    tokenized_sentences = [nltk.word_tokenize(sentence.lower()) for sentence in sentences]
    
    
    english_stopwords = set(stopwords.words('english'))
    
    
    processed_sentences = [[word for word in words if word not in english_stopwords ] for words in tokenized_sentences]
    
    
    stemmer = PorterStemmer()
    processed_sentences = [[stemmer.stem(word) for word in words] for words in processed_sentences]
    
    return processed_sentences

df['fullplot'] = df['fullplot'].apply(preprocess_sentences)
df['fullplot'] = df['fullplot'].apply(lambda x: x[0])

# %%
df.head(3)
# Out:
#        imdbID              title                       genre        director  \
# 2008    35423     Kate & Leopold  [comedy, fantasy, romance]  [jamesmangold]
# 7011    64994  Larks on a String    [comedy, drama, romance]    [jir�menzel]
# 10044   81145     Me and the Kid      [comedy, crime, drama]     [dancurtis]
#
#                                                     cast imdbRating  \
# 2008   [megryan, hughjackman, lievschreiber, breckinm...      [6.3]
# 7011   [rudolfhrus�nsk�, vlastimilbrodsk�, v�clavneck...      [7.6]
# 10044  [dannyaiello, alexzuckerman, joepantoliano, ca...      [5.3]
#
#                                                 fullplot           language  \
# 2008   [kate, actor, brother, live, ny, 21st, centuri...  [english, french]
# 7011   [pragu, earli, 1950, bourgeoi, element, reeduc...            [czech]
# 10044                                       [two, excon]          [english]
#
#                 country     type    decade
# 2008              [usa]  [movie]  [2000.0]
# 7011   [czechoslovakia]  [movie]  [1990.0]
# 10044             [usa]  [movie]  [1990.0]

# %%
## Joining the column together 

df['meta_tags'] = df['genre'] + df['director'] + df['cast'] + df['imdbRating'] + df['language'] + df['country'] + df['type'] +df['decade'] 
df['all tags']  = df['fullplot'] + df['meta_tags']

# %%
df.drop(['genre','director','cast','imdbRating','language','country','type','decade'],axis=1,inplace=True)

# %%
df['fullplot'] = df['fullplot'].apply(lambda x: ' '.join(x))
df['meta_tags'] = df['meta_tags'].apply(lambda x: ' '.join(x))
df['all tags'] = df['all tags'].apply(lambda x: ' '.join(x))

# %%
df.head(3)
# Out:
#        imdbID              title  \
# 2008    35423     Kate & Leopold
# 7011    64994  Larks on a String
# 10044   81145     Me and the Kid
#
#                                                 fullplot  \
# 2008   kate actor brother live ny 21st centuri exboyf...
# 7011   pragu earli 1950 bourgeoi element reeduc work ...
# 10044                                          two excon
#
#                                                meta_tags  \
# 2008   comedy fantasy romance jamesmangold megryan hu...
# 7011   comedy drama romance jir�menzel rudolfhrus�nsk...
# 10044  comedy crime drama dancurtis dannyaiello alexz...
#
#                                                 all tags
# 2008   kate actor brother live ny 21st centuri exboyf...
# 7011   pragu earli 1950 bourgeoi element reeduc work ...
# 10044  two excon comedy crime drama dancurtis dannyai...

# %%
df.to_pickle("preprocessed_dataset.pkl")
